# %%
# Plotting Classification Trees with the plot.rpart and rattle pckages

library(rpart)				        # Popular decision tree algorithm
library(rattle)					# Fancy tree plot
library(rpart.plot)				# Enhanced tree plots
library(RColorBrewer)				# Color selection for fancy tree plot
library(party)					# Alternative decision tree algorithm
library(partykit)				# Convert rpart object to BinaryTree
library(caret)					# Just a data source for this script
# but probably one of the best R packages ever.
# Out:
# Warning message:
# "package 'rattle' was built under R version 3.4.2"Rattle: A free graphical interface for data science with R.
# バージョン 5.1.0 Copyright (c) 2006-2017 Togaware Pty Ltd.
# 'rattle()' と入力して、データを多角的に分析します。
# Warning message:
# "package 'rpart.plot' was built under R version 3.4.2"Warning message:
# "package 'party' was built under R version 3.4.2"Loading required package: grid
# Loading required package: mvtnorm
# Loading required package: modeltools
# Loading required package: stats4
# Loading required package: strucchange
# Warning message:
# "package 'strucchange' was built under R version 3.4.2"Loading required package: zoo
#
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#
# Loading required package: sandwich
# Warning message:
# "package 'sandwich' was built under R version 3.4.2"
# Attaching package: 'partykit'
#
# The following objects are masked from 'package:party':
#
#     cforest, ctree, ctree_control, edge_simple, mob, mob_control,
#     node_barplot, node_bivplot, node_boxplot, node_inner, node_surv,
#     node_terminal
#
# Loading required package: lattice
# Loading required package: ggplot2

# %%
data(segmentationData)

# %%
data <- segmentationData[,-c(1,2)]

# %%
head(data,1)
# Out:
#   Class AngleCh1 AreaCh1 AvgIntenCh1 AvgIntenCh2 AvgIntenCh3 AvgIntenCh4
# 1 PS    143.2477 185     15.71186    4.954802    9.548023    2.214689
#   ConvexHullAreaRatioCh1 ConvexHullPerimRatioCh1 DiffIntenDensityCh1 ...
# 1 1.124509               0.9196827               29.51923            ...
#   TotalIntenCh1 TotalIntenCh2 TotalIntenCh3 TotalIntenCh4 VarIntenCh1
# 1 2781          701           1690          392           12.47468
#   VarIntenCh3 VarIntenCh4 WidthCh1 XCentroid YCentroid
# 1 7.609035    2.7141      10.64297 42        14

# %%
# Make big tree
form <- as.formula(Class ~ .)
tree.1 <- rpart(form,data=data,control=rpart.control(minsplit=20,cp=0))

# %%
# 
plot(tree.1)					# Will make a mess of the plot
text(tree.1)
# Out:
# plot without title

# %%
# 
prp(tree.1)					# Will plot the tree
prp(tree.1,varlen=3)				# Shorten variable names
# Out:
# plot without title
# plot without title

# %%
tree.2 <- rpart(form,data)			# A more reasonable tree
prp(tree.2)                                     # A fast plot													
fancyRpartPlot(tree.2)				# A fancy plot from rattle
# Out:
# plot without title
# Plot with title ""
